# %%
import pandas as pd

# %%
from pathlib import Path

# %%
path_to_data = Path("../data")

# %%
path_to_csv = path_to_data / ("banknotesData.csv")

# %%
notes_df = pd.read_csv(path_to_csv)

# %%
notes_df.head()
# Out:
#      country countryAbbr      currencyName                        name gender  \
# 0  Argentina         ARS  Argentinian Peso                   Eva Perón      F
# 1  Argentina         ARS  Argentinian Peso        Julio Argentino Roca      M
# 2  Argentina         ARS  Argentinian Peso  Domingo Faustino Sarmiento      M
# 3  Argentina         ARS  Argentinian Peso        Juan Manuel de Rosas      M
# 4  Argentina         ARS  Argentinian Peso             Manuel Belgrano      M
#
#    billCount     profession knownForBeingFirst  currentBillValue  \
# 0        1.0       Activist                 No               100
# 1        1.0  Head of Gov't                 No               100
# 2        1.0  Head of Gov't                 No                50
# 3        1.0     Politician                 No                20
# 4        1.0        Founder                Yes                10
#
#    propTotalBills  firstAppearanceDate deathDate  appearanceDeathDiff  \
# ...

# %%
notes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              279 non-null    object
#  1   countryAbbr          279 non-null    object
#  2   currencyName         279 non-null    object
#  3   name                 279 non-null    object
#  4   gender               279 non-null    object
#  5   billCount            279 non-null    float64
#  6   profession           279 non-null    object
#  7   knownForBeingFirst   279 non-null    object
#  8   currentBillValue     279 non-null    int64
#  9   propTotalBills       59 non-null     float64
#  10  firstAppearanceDate  279 non-null    int64
#  11  deathDate            272 non-null    object
#  12  appearanceDeathDiff  271 non-null    float64
#  13  comments             119 non-null    object
#  14  hoverText            89 non-null     object
# ...

# %%
notes_df.isna().sum().sum()
# Out:
# np.int64(585)

# %%
missing_deathDate = notes_df.copy(deep=True)

# %%
missing_deathDate = missing_deathDate[missing_deathDate["deathDate"].isna()]

# %%
missing_deathDate
# Out:
#          country countryAbbr        currencyName                name gender  \
# 13     Australia         AUD   Australian Dollar  Queen Elizabeth II      F
# 37       Bolivia         BOB           Boliviano       Genoveva Ríos      F
# 101      England         GBP               pound  Queen Elizabeth II      F
# 102      England         GBP               pound  Queen Elizabeth II      F
# 103      England         GBP               pound  Queen Elizabeth II      F
# 104      England         GBP               pound  Queen Elizabeth II      F
# 172  New Zealand         NZD  New Zealand dollar  Queen Elizabeth II      F
#
#      billCount profession knownForBeingFirst  currentBillValue  \
# 13        1.00    Monarch                 No                 5
# 37        0.33      Other                 No                20
# 101       0.50    Monarch                 No                 5
# 102       0.50    Monarch                 No                10
# ...

# %%
missing_appearanceDeathDiff = notes_df.copy(deep=True)

# %%
missing_appearanceDeathDiff = missing_appearanceDeathDiff[missing_appearanceDeathDiff["appearanceDeathDiff"].isna()]

# %%
missing_appearanceDeathDiff
# Out:
#          country countryAbbr        currencyName                name gender  \
# 13     Australia         AUD   Australian Dollar  Queen Elizabeth II      F
# 37       Bolivia         BOB           Boliviano       Genoveva Ríos      F
# 46        Canada         CAD     Canadian Dollar  Queen Elizabeth II      F
# 101      England         GBP               pound  Queen Elizabeth II      F
# 102      England         GBP               pound  Queen Elizabeth II      F
# 103      England         GBP               pound  Queen Elizabeth II      F
# 104      England         GBP               pound  Queen Elizabeth II      F
# 172  New Zealand         NZD  New Zealand dollar  Queen Elizabeth II      F
#
#      billCount profession knownForBeingFirst  currentBillValue  \
# 13        1.00    Monarch                 No                 5
# 37        0.33      Other                 No                20
# 46        1.00    Monarch                 No                20
# ...

# %%
notes_df.loc[notes_df["name"] == "Queen Elizabeth II", "deathDate"] = 2022

# %%
notes_df.loc[notes_df["name"] == "Genoveva Ríos", "deathDate"] = "unknown"

# %%
notes_df.isna().sum().sum()
# Out:
# np.int64(578)

# %%
notes_df["deathDate"] = pd.to_numeric(notes_df["deathDate"], errors="coerce").astype("Int64")

# %%
notes_df['deathDate'].isna().sum()
# Out:
# np.int64(1)

# %%
notes_df["appearanceDeathDiff"] = notes_df["firstAppearanceDate"] - notes_df["deathDate"]

# %%
notes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279 entries, 0 to 278
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              279 non-null    object
#  1   countryAbbr          279 non-null    object
#  2   currencyName         279 non-null    object
#  3   name                 279 non-null    object
#  4   gender               279 non-null    object
#  5   billCount            279 non-null    float64
#  6   profession           279 non-null    object
#  7   knownForBeingFirst   279 non-null    object
#  8   currentBillValue     279 non-null    int64
#  9   propTotalBills       59 non-null     float64
#  10  firstAppearanceDate  279 non-null    int64
#  11  deathDate            278 non-null    Int64
#  12  appearanceDeathDiff  278 non-null    Int64
#  13  comments             119 non-null    object
#  14  hoverText            89 non-null     object
# ...

# %%
notes_df.head()
# Out:
#      country countryAbbr      currencyName                        name gender  \
# 0  Argentina         ARS  Argentinian Peso                   Eva Perón      F
# 1  Argentina         ARS  Argentinian Peso        Julio Argentino Roca      M
# 2  Argentina         ARS  Argentinian Peso  Domingo Faustino Sarmiento      M
# 3  Argentina         ARS  Argentinian Peso        Juan Manuel de Rosas      M
# 4  Argentina         ARS  Argentinian Peso             Manuel Belgrano      M
#
#    billCount     profession knownForBeingFirst  currentBillValue  \
# 0        1.0       Activist                 No               100
# 1        1.0  Head of Gov't                 No               100
# 2        1.0  Head of Gov't                 No                50
# 3        1.0     Politician                 No                20
# 4        1.0        Founder                Yes                10
#
#    propTotalBills  firstAppearanceDate  deathDate  appearanceDeathDiff  \
# ...
